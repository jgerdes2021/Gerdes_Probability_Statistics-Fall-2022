# %% [markdown]
# <a href="https://colab.research.google.com/github/jgerdes2021/Gerdes_Probability_Statistics-Fall-2022/blob/main/Gerdes_Midterm_Take_Home_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# :https://setosa.io/ev/ordinary-least-squares-regression/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Linear Fit with Real Data
#
# Required Tools: Ruler and String
#
# 1.   Collect 5 round objects (Wheel, Jar, Frisbee, etc)
# 2.   For each object measure the diameter and circumfrence and create a table like that shown below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Replace the values below with the values from your table

# %%
D = np.array([12,9,20,7,2])    # <- Put your numbers here  Diameter
C = np.array([38,28,63,22,6])  #                           Circumference

# %%
#numbers from the chart

# %%
plt.plot(D,C,'.')

# %%
#variable d stands for diameter and c for circumference

# %%
x = D
y = C

# %%
m_guess = 0 
b_guess = 0

# %%
#guessing m and b as zero

# %%
x
# Out:
# array([12,  9, 20,  7,  2])

# %%
#the x-coordinates

# %%
y_guess = m_guess * x + b_guess

# %%
#y_guess = m_guess * x + b_guess, is similar to y = mx+b

# %%
y_guess
# Out:
# array([0, 0, 0, 0, 0])

# %%
#rename the variables D and C as X and Y

# %%
best_loss = 1000000000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-100,100,100):
    for b_guess in np.linspace(-100,100,100):
        
        print("Now Testing: ", m_guess, b_guess)

        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess
# Out:
# Streaming output truncated to the last 5000 lines.
# Now Testing:  1.0101010101010104 -100.0
# Now Testing:  1.0101010101010104 -97.97979797979798
# Now Testing:  1.0101010101010104 -95.95959595959596
# Now Testing:  1.0101010101010104 -93.93939393939394
# Now Testing:  1.0101010101010104 -91.91919191919192
# Now Testing:  1.0101010101010104 -89.8989898989899
# Now Testing:  1.0101010101010104 -87.87878787878788
# Now Testing:  1.0101010101010104 -85.85858585858585
# Now Testing:  1.0101010101010104 -83.83838383838383
# Now Testing:  1.0101010101010104 -81.81818181818181
# Now Testing:  1.0101010101010104 -79.79797979797979
# Now Testing:  1.0101010101010104 -77.77777777777777
# Now Testing:  1.0101010101010104 -75.75757575757575
# Now Testing:  1.0101010101010104 -73.73737373737373
# Now Testing:  1.0101010101010104 -71.71717171717171
# Now Testing:  1.0101010101010104 -69.69696969696969
# Now Testing:  1.0101010101010104 -67.67676767676767
# ...

# %%
#searching for all possible values of b and m

# %%
y_guess = best_m * x + best_b

plt.plot(x,y_guess,'r');
plt.plot(D,C,'g.');
plt.show()

print(best_loss,best_m,best_b)
# Out:
# 3.583001734516836 3.030303030303031 1.0101010101010104

# %%
#the data points

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([12,9,20,7,2])   
Y = np.array([38,28,63,22,6])

# %%
#X and Y data set

# %%
plt.plot(X,Y,'g.')

# %%
#the 'g.' allows the graph to be green

# %%
m_guess = 0 
b_guess = 0

# %% [markdown]
# $y=mx+b$

# %%
m_guess * X + b_guess
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_guess = m_guess * X + b_guess

# %%
y_guess - Y
# Out:
# array([-38, -28, -63, -22,  -6])

# %%
#subtracting from the line to the data point, testing how well the model fits the data

# %%
y_guess - Y ** 2
# Out:
# array([-1444,  -784, -3969,  -484,   -36])

# %%
#squared the numbers to get rid of the minus signs

# %%
np.sum((y_guess - Y)** 2)
# Out:
# 6717

# %%
#get the sum of the line

# %%
loss = np.sum((y_guess - Y)**2)

# %%
b_guess

for m_guess in np.linspace(-100,100,100):
    print(m_guess,b_guess)
    y_guess = m_guess * X + b_guess
# Out:
# -100.0 0
# -97.97979797979798 0
# -95.95959595959596 0
# -93.93939393939394 0
# -91.91919191919192 0
# -89.8989898989899 0
# -87.87878787878788 0
# -85.85858585858585 0
# -83.83838383838383 0
# -81.81818181818181 0
# -79.79797979797979 0
# -77.77777777777777 0
# -75.75757575757575 0
# -73.73737373737373 0
# -71.71717171717171 0
# -69.69696969696969 0
# -67.67676767676767 0
# -65.65656565656565 0
# -63.63636363636363 0
# -61.61616161616161 0
# -59.59595959595959 0
# -57.57575757575757 0
# -55.55555555555555 0
# -53.53535353535353 0
# -51.515151515151516 0
# -49.494949494949495 0
# -47.474747474747474 0
# -45.45454545454545 0
# -43.43434343434343 0
# -41.41414141414141 0
# -39.39393939393939 0
# -37.37373737373737 0
# -35.35353535353535 0
# -33.33333333333333 0
# -31.313131313131308 0
# -29.292929292929287 0
# -27.272727272727266 0
# -25.252525252525245 0
# -23.232323232323225 0
# -21.212121212121204 0
# -19.191919191919183 0
# -17.171717171717162 0
# -15.151515151515142 0
# ...

# %%
#linear regression

# %%
best_loss_so_far = 1000000000000
m_best = 0 
b_best = 0 
for m_guess in np.linspace(-100,100,100):
    for b_guess in np.linspace(-100,100,100):
        
        y_guess = m_guess * X + b_guess

        loss = np.sum((y_guess - Y)**2)

        if loss < best_loss_so_far:
            m_best = m_guess
            b_best = b_guess
            best_loss_so_far = loss

print("Found best fit:")
print(m_best,b_best,loss)
# Out:
# Found best fit:
# 3.030303030303031 1.0101010101010104 7378517.0

# %%
#subtract the output from the guess, take the difference, square them to negatives don't cancel out and sum it up

# %% [markdown]
# *The* estimated relationship is:
#
# $C = ? D + ?$

# %% [markdown]
# ## Part 3: Interpretation

# %% [markdown]
# #### Question 1:
#
# What do $m$ and $b$ represent in these equations?

# %% [markdown]
# m and b are variables in the equation, y = mx+b, m is the slope and b is the y-intercept.

# %% [markdown]
# #### Question 2:
#
# Guess what the correct values $m$ and $b$ should be.

# %% [markdown]
# I think the correct value of m is 3.030303030303031 and b is 1.0101010101010104 7378517.0 as these are the best fit values

# %% [markdown]
# #### Question 3:
#
# Does it make sense to include $b$ in the parameters?

# %% [markdown]
# I think it does makes sense to include b in the parameters as in the equation y = mx+b, y and x are the varaibles, m is the slope, and b is the y-intercept. They are all included for plotting the equation.
